# %% [markdown]
# # Exploring the MIOFlow outputs

# %% [markdown]
# The original data was in the folder: /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Multiome/results_new/bleo/traj_gene_sp.npy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import re
import scipy.stats as stats

from src.dataset import main

# %%
mioflow_object = np.load('../data/raw/traj_gene_sp.npy')
mioflow_object.shape
# Out:
# (100, 100, 32285)

# %%
type(mioflow_object)
# Out:
# numpy.ndarray

# %%
import torch

# %%
mioflow_tensor = torch.from_numpy(mioflow_object)

# %%
torch.save(mioflow_tensor, '../data/raw/traj_genes_sp.pt')

# %%
import torch_geometric

# %%
tu_dataset = torch_geometric.datasets.TUDataset(root='.', name="MUTAG")
# Out:
# ...
# Processing...
# Done!

# %%
tu_dataset.get(0)
# Out:
# Data(edge_index=[2, 38], x=[17, 7], edge_attr=[38, 4], y=[1])

# %%
print("Data object:", tu_dataset.data)
print("Length:", len(tu_dataset))
print(f"Average label: {tu_dataset.data.y.float().mean().item():4.2f}")
# Out:
# Data object: Data(x=[3371, 7], edge_index=[2, 7442], edge_attr=[7442, 4], y=[188])
# Length: 188
# Average label: 0.66
# /Users/joaofelipe/miniconda3/envs/staged/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %%
mioflow_tensor[0,0,:]
# Out:
# tensor([5.5313e-03, 1.0963e-03, 5.5084e-04,  ..., 0.0000e+00, 0.0000e+00,
#         1.0844e+00], dtype=torch.float64)

# %%
mioflow_tensor.shape
# Out:
# torch.Size([100, 100, 32285])

# %% [markdown]
# ## Using RITINI code

# %%
X = mioflow_object
(time, num_genes, num_cells_per_type) = X.shape

mean_expr = np.mean(X, axis=2)
