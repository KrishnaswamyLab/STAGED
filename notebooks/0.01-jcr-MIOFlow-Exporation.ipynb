# %% [markdown]
# # Exploring the MIOFlow outputs

# %% [markdown]
# The original data was in the folder: /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Multiome/results_new/bleo/traj_gene_sp.npy

# %%
# %load_ext autoreload
# %autoreload 2


import numpy as np
import pandas as pd
import re
import scipy.stats as stats

from staged.dataset import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mioflow_object = np.load('../data/raw/traj_gene_sp.npy')
mioflow_object.shape
# Out:
# (100, 100, 32285)

# %% [markdown]
# ## Using RITINI code

# %%
import os, sys, json, pickle, itertools, numpy as np, pandas as pd, scipy.sparse as sp
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.metrics import roc_auc_score
import networkx as nx

import torch, torch.nn as nn, torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR

# import dgl, dgl.nn.pytorch.conv as conv

# import phate, umap

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X = mioflow_object
(time, num_genes, num_cells_per_type) = X.shape

mean_expr = np.mean(X, axis=2)

# %% [markdown]
# # Define cell types for the dataset

# %%
X
# Out:
# array([[[5.53128857e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.34067517e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [6.88851141e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [7.52989794e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [5.71815549e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.62877310e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]],
#
#        [[6.05820648e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.36390310e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [7.81179521e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [8.59385779e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [6.31328546e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.68510580e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]],
#
#        [[6.67439400e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.39143928e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [8.83638221e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [9.58676318e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [6.91748397e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.72571002e-02, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]],
#
#        ...,
#
#        [[3.66789557e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [2.78966449e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [3.27960666e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [3.18087922e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [3.97426029e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.53543793e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]],
#
#        [[3.60946615e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [2.45978070e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [3.08491948e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [2.97932579e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [4.02574472e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [1.12568510e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]],
#
#        [[3.71429800e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [2.12177061e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [2.87905888e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         ...,
#         [2.76758025e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [4.11907630e-03, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00],
#         [6.20575107e-04, 1.09629247e-03, 5.50837526e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 1.08441963e+00]]],
#       shape=(100, 100, 32285))

# %% [markdown]
# # Need to compute the prior Graph

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 grn_graph = nx.Graph(list(df_edges.itertuples(index=False)))
#       2 grn_graph_pos = nx.spring_layout(grn_graph)
#
# NameError: name 'df_edges' is not defined
