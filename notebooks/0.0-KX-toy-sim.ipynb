# %%
import sys
sys.path.append('/gpfs/gibbs/pi/krishnaswamy_smita/kx44/projects/STAGED')
from src.data.simulation import CellSimulation
# Out:
# /gpfs/gibbs/project/gerstein/kx44/conda_envs/WasteWatcher/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /lib64/libm.so.6: version `GLIBC_2.29' not found (required by /gpfs/gibbs/project/gerstein/kx44/conda_envs/WasteWatcher/lib/python3.10/site-packages/libpyg.so)
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /gpfs/gibbs/project/gerstein/kx44/conda_envs/WasteWatcher/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /gpfs/gibbs/project/gerstein/kx44/conda_envs/WasteWatcher/lib/python3.10/site-packages/torch_scatter/_scatter_cuda.so: undefined symbol: _ZN2at4_ops16div__Tensor_mode4callERNS_6TensorERKS2_St8optionalIN3c1017basic_string_viewIcEEE
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# ...

# %%
# Create simulation
sim = CellSimulation(num_cells=4, nodes_per_cell=5, delta1 = 1, delta2=2, delta3=3, deltal=5)

# Set initial conditions - first gene in first cell is active
sim.initialize_expression()

# Run simulation
history = sim.run_simulation(steps=50)

# Create animation
sim.animate_network(history, fps=1, output_path="network_simulation.gif")
# Out:
# Animation saved to network_simulation.gif

# %%
sim.plot_expression_over_time(history, gene_idx=4)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Receptor Expression Over Time'}, xlabel='Time Steps', ylabel='Expression Level'>)
